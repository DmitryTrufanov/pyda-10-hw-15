# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
players_season = pd.read_csv('Seasons_Stats.csv')
players_season.head()
# Out:
#    Unnamed: 0    Year           Player  Pos   Age   Tm     G  GS  MP  PER  \
# 0           0  1950.0  Curly Armstrong  G-F  31.0  FTW  63.0 NaN NaN  NaN
# 1           1  1950.0     Cliff Barker   SG  29.0  INO  49.0 NaN NaN  NaN
# 2           2  1950.0    Leo Barnhorst   SF  25.0  CHS  67.0 NaN NaN  NaN
# 3           3  1950.0       Ed Bartels    F  24.0  TOT  15.0 NaN NaN  NaN
# 4           4  1950.0       Ed Bartels    F  24.0  DNN  13.0 NaN NaN  NaN
#
#    ...    FT%  ORB  DRB  TRB    AST  STL  BLK  TOV     PF    PTS
# 0  ...  0.705  NaN  NaN  NaN  176.0  NaN  NaN  NaN  217.0  458.0
# 1  ...  0.708  NaN  NaN  NaN  109.0  NaN  NaN  NaN   99.0  279.0
# 2  ...  0.698  NaN  NaN  NaN  140.0  NaN  NaN  NaN  192.0  438.0
# 3  ...  0.559  NaN  NaN  NaN   20.0  NaN  NaN  NaN   29.0   63.0
# 4  ...  0.548  NaN  NaN  NaN   20.0  NaN  NaN  NaN   27.0   59.0
#
# [5 rows x 53 columns]

# %%
players_season.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24691 entries, 0 to 24690
# Data columns (total 53 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  24691 non-null  int64
#  1   Year        24624 non-null  float64
#  2   Player      24624 non-null  object
#  3   Pos         24624 non-null  object
#  4   Age         24616 non-null  float64
#  5   Tm          24624 non-null  object
#  6   G           24624 non-null  float64
#  7   GS          18233 non-null  float64
#  8   MP          24138 non-null  float64
#  9   PER         24101 non-null  float64
#  10  TS%         24538 non-null  float64
#  11  3PAr        18839 non-null  float64
#  12  FTr         24525 non-null  float64
#  13  ORB%        20792 non-null  float64
#  14  DRB%        20792 non-null  float64
#  15  TRB%        21571 non-null  float64
#  16  AST%        22555 non-null  float64
#  17  STL%        20792 non-null  float64
#  18  BLK%        20792 non-null  float64
#  19  TOV%        19582 non-null  float64
#  20  USG%        19640 non-null  float64
#  21  blanl       0 non-null      float64
#  22  OWS         24585 non-null  float64
#  23  DWS         24585 non-null  float64
#  24  WS          24585 non-null  float64
#  25  WS/48       24101 non-null  float64
#  26  blank2      0 non-null      float64
#  27  OBPM        20797 non-null  float64
#  28  DBPM        20797 non-null  float64
#  29  BPM         20797 non-null  float64
#  30  VORP        20797 non-null  float64
#  31  FG          24624 non-null  float64
#  32  FGA         24624 non-null  float64
#  33  FG%         24525 non-null  float64
#  34  3P          18927 non-null  float64
#  35  3PA         18927 non-null  float64
#  36  3P%         15416 non-null  float64
#  37  2P          24624 non-null  float64
#  38  2PA         24624 non-null  float64
#  39  2P%         24496 non-null  float64
#  40  eFG%        24525 non-null  float64
#  41  FT          24624 non-null  float64
#  42  FTA         24624 non-null  float64
#  43  FT%         23766 non-null  float64
#  44  ORB         20797 non-null  float64
#  45  DRB         20797 non-null  float64
#  46  TRB         24312 non-null  float64
#  47  AST         24624 non-null  float64
#  48  STL         20797 non-null  float64
#  49  BLK         20797 non-null  float64
#  50  TOV         19645 non-null  float64
#  51  PF          24624 non-null  float64
#  52  PTS         24624 non-null  float64
# dtypes: float64(49), int64(1), object(3)
# memory usage: 10.0+ MB

# %%
kobe = players_season[players_season['Player'] == 'Kobe Bryant']
kobe['Year'] = kobe.Year.astype('int64')
kobe
# Out:
# C:\Users\Dmitry\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 21757  ...  0.839   66.0  367.0  433.0  469.0  106.0  25.0  287.0  173.0
# 22348  ...  0.857    2.0   24.0   26.0   38.0    7.0   1.0   34.0    9.0
# 22944  ...  0.813   26.0  173.0  199.0  197.0   47.0   7.0  128.0   65.0
# 23586  ...  0.826   41.0  206.0  247.0  184.0   62.0  13.0  129.0  115.0
#
#           PTS
# 12900   539.0
# 13479  1220.0
# 14021   996.0
# 14537  1485.0
# 15028  1938.0
# 15578  2019.0
# 16070  2461.0
# 16576  1557.0
# 17159  1819.0
# 17742  2832.0
# 18295  2430.0
# 18825  2323.0
# 19428  2201.0
# 20006  1970.0
# 20600  2078.0
# 21196  1616.0
# 21757  2133.0
# 22348    83.0
# 22944   782.0
# 23586  1161.0
#
# [20 rows x 53 columns]

# %% [markdown]
# **столбчатая диаграмма**

# %%
# переменные: PTS - набранные очки, FGA - выполенено бросков.
# В графике приведено соотношение набранных очков и совершенных бросков.
# после получения травмы в 2014 соотношение ухудшилось (приблизительно 1 очко на один бросок)
Kobe_points = kobe[['Year', 'PTS', 'FGA']].plot(kind='bar', x='Year', figsize=(20, 4), title='соотношение набранных очков и выполненных бросков Kobe Bryant')

# %% [markdown]
# **график**

# %%
# переменные: FG% - % попадания.
# на линейчатом графике отчетлива видна динамика изменения % точности.
Kobe_points2 = kobe[['Year','FG%']].plot(kind='area', x='Year', xticks=(range(1997, 2017)), ylim=0.35, figsize=(20, 4), grid=True, title='% точности Kobe Bryant')
# если добавить атрибут kind='area', то изменяется начальная точка оси У на о. Как настроить ось?

# %% [markdown]
# **круговая диаграмма**

# %%
#переменные: 2P - кол-во точных 2 оч. бросков, 3P - кол-во точных 3 оч. бросков, FT - кол-во точных штрафных, 
#TRB - подборы, AST - передачи, STL - перехваты, BLK - блокшоты

# график отображает игровые особенности игрока: атакующие - много 2 оч.бросков и штрафных, 3 оч.бросков значительно меньше
# активность на подборах и передачи также сильно развита. 

Kobe_skills = kobe[['2P', '3P', 'FT', 'TRB', 'AST', 'STL', 'BLK']].sum()
Kobe_skills.reset_index()
#Kobe_skills.stack().reset_index()
Kobe_skills.plot(kind='pie', y='0', title='Скилы Kobe Bryant')

# %% [markdown]
# **спарклайн**

# %%
#1.группировка
#2.применение функций к столбцам
#3.сортировка
#4.стилизация таблицы - спарклайн

#датафрейм отсортирован по количеству набранных очков (PTS), но количество сезонов, которое понадобилось для набора очков различно,
# т.е. если смотреть в среднем за сезон, то ТОП-15 будет выглядить иначе

top_15_players = players_season[['Player', 'Year', 'PTS', '2P', '3P', 'FT']].groupby('Player')\
    .agg({'Year': 'count', 'PTS': 'sum', '2P': 'sum', '3P': 'sum', 'FT': 'sum'})\
        .sort_values('PTS', ascending=False).reset_index().head(15)\
            .style.bar('Year') #после применения спарклайна почему-то во всех столбцах увеличилось кол-во знаков после запятой
top_15_players
# Out:
# <style  type="text/css" >
#     #T_6ae52bd8_c4e8_11ea_91e5_94de80aece86row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 31.6%, transparent 31.6%);
#         }    #T_6ae52bd8_c4e8_11ea_91e5_94de80aece86row1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 26.3%, transparent 26.3%);
#         }    #T_6ae52bd8_c4e8_11ea_91e5_94de80aece86row2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 10.5%, transparent 10.5%);
#         }    #T_6ae52bd8_c4e8_11ea_91e5_94de80aece86row3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 31.6%, transparent 31.6%);
#         }    #T_6ae52bd8_c4e8_11ea_91e5_94de80aece86row4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 5.3%, transparent 5.3%);
#         }    #T_6ae52bd8_c4e8_11ea_91e5_94de80aece86row5_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
#         }    #T_6ae52bd8_c4e8_11ea_91e5_94de80aece86row6_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 26.3%, transparent 26.3%);
#         }    #T_6ae52bd8_c4e8_11ea_91e5_94de80aece86row7_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 36.8%, transparent 36.8%);
#         }    #T_6ae52bd8_c4e8_11ea_91e5_94de80aece86row8_col1 {
#             width:  10em;
#              height:  80%;
#         }    #T_6ae52bd8_c4e8_11ea_91e5_94de80aece86row9_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 15.8%, transparent 15.8%);
#         }    #T_6ae52bd8_c4e8_11ea_91e5_94de80aece86row10_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 36.8%, transparent 36.8%);
#         }    #T_6ae52bd8_c4e8_11ea_91e5_94de80aece86row11_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 47.4%, transparent 47.4%);
#         }    #T_6ae52bd8_c4e8_11ea_91e5_94de80aece86row12_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 31.6%, transparent 31.6%);
#         }    #T_6ae52bd8_c4e8_11ea_91e5_94de80aece86row13_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 10.5%, transparent 10.5%);
#         }    #T_6ae52bd8_c4e8_11ea_91e5_94de80aece86row14_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 21.1%, transparent 21.1%);
#         }</style><table id="T_6ae52bd8_c4e8_11ea_91e5_94de80aece86" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Player</th>        <th class="col_heading level0 col1" >Year</th>        <th class="col_heading level0 col2" >PTS</th>        <th class="col_heading level0 col3" >2P</th>        <th class="col_heading level0 col4" >3P</th>        <th class="col_heading level0 col5" >FT</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6ae52bd8_c4e8_11ea_91e5_94de80aece86level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_6ae52bd8_c4e8_11ea_91e5_94de80aece86row0_col0" class="data row0 col0" >Kareem Abdul-Jabbar*</td>
#                         <td id="T_6ae52bd8_c4e8_11ea_91e5_94de80aece86row0_col1" class="data row0 col1" >20</td>
#                         <td id="T_6ae52bd8_c4e8_11ea_91e5_94de80aece86row0_col2" class="data row0 col2" >38387.000000</td>
#                         <td id="T_6ae52bd8_c4e8_11ea_91e5_94de80aece86row0_col3" class="data row0 col3" >15836.000000</td>
#                         <td id="T_6ae52bd8_c4e8_11ea_91e5_94de80aece86row0_col4" class="data row0 col4" >1.000000</td>
#                         <td id="T_6ae52bd8_c4e8_11ea_91e5_94de80aece86row0_col5" class="data row0 col5" >6712.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_6ae52bd8_c4e8_11ea_91e5_94de80aece86level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_6ae52bd8_c4e8_11ea_91e5_94de80aece86row1_col0" class="data row1 col0" >Karl Malone*</td>
#                         <td id="T_6ae52bd8_c4e8_11ea_91e5_94de80aece86row1_col1" class="data row1 col1" >19</td>
#                         <td id="T_6ae52bd8_c4e8_11ea_91e5_94de80aece86row1_col2" class="data row1 col2" >36928.000000</td>
#                         <td id="T_6ae52bd8_c4e8_11ea_91e5_94de80aece86row1_col3" class="data row1 col3" >13443.000000</td>
#                         <td id="T_6ae52bd8_c4e8_11ea_91e5_94de80aece86row1_col4" class="data row1 col4" >85.000000</td>
#                         <td id="T_6ae52bd8_c4e8_11ea_91e5_94de80aece86row1_col5" class="data row1 col5" >9787.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_6ae52bd8_c4e8_11ea_91e5_94de80aece86level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_6ae52bd8_c4e8_11ea_91e5_94de80aece86row2_col0" class="data row2 col0" >Wilt Chamberlain*</td>
#                         <td id="T_6ae52bd8_c4e8_11ea_91e5_94de80aece86row2_col1" class="data row2 col1" >16</td>
#                         <td id="T_6ae52bd8_c4e8_11ea_91e5_94de80aece86row2_col2" class="data row2 col2" >33953.000000</td>
#                         <td id="T_6ae52bd8_c4e8_11ea_91e5_94de80aece86row2_col3" class="data row2 col3" >13744.000000</td>
#                         <td id="T_6ae52bd8_c4e8_11ea_91e5_94de80aece86row2_col4" class="data row2 col4" >0.000000</td>
#                         <td id="T_6ae52bd8_c4e8_11ea_91e5_94de80aece86row2_col5" class="data row2 col5" >6465.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_6ae52bd8_c4e8_11ea_91e5_94de80aece86level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_6ae52bd8_c4e8_11ea_91e5_94de80aece86row3_col0" class="data row3 col0" >Kobe Bryant</td>
#                         <td id="T_6ae52bd8_c4e8_11ea_91e5_94de80aece86row3_col1" class="data row3 col1" >20</td>
#                         <td id="T_6ae52bd8_c4e8_11ea_91e5_94de80aece86row3_col2" class="data row3 col2" >33643.000000</td>
#                         <td id="T_6ae52bd8_c4e8_11ea_91e5_94de80aece86row3_col3" class="data row3 col3" >9892.000000</td>
#                         <td id="T_6ae52bd8_c4e8_11ea_91e5_94de80aece86row3_col4" class="data row3 col4" >1827.000000</td>
#                         <td id="T_6ae52bd8_c4e8_11ea_91e5_94de80aece86row3_col5" class="data row3 col5" >8378.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_6ae52bd8_c4e8_11ea_91e5_94de80aece86level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_6ae52bd8_c4e8_11ea_91e5_94de80aece86row4_col0" class="data row4 col0" >Michael Jordan*</td>
#                         <td id="T_6ae52bd8_c4e8_11ea_91e5_94de80aece86row4_col1" class="data row4 col1" >15</td>
#                         <td id="T_6ae52bd8_c4e8_11ea_91e5_94de80aece86row4_col2" class="data row4 col2" >32292.000000</td>
#                         <td id="T_6ae52bd8_c4e8_11ea_91e5_94de80aece86row4_col3" class="data row4 col3" >11611.000000</td>
#                         <td id="T_6ae52bd8_c4e8_11ea_91e5_94de80aece86row4_col4" class="data row4 col4" >581.000000</td>
#                         <td id="T_6ae52bd8_c4e8_11ea_91e5_94de80aece86row4_col5" class="data row4 col5" >7327.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_6ae52bd8_c4e8_11ea_91e5_94de80aece86level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_6ae52

# %% [markdown]
# **столбчатая диаграмма с накоплением**

# %%
# набор бросков топ 15 играков по количеству точных бросков
#на графике можно увидеть насколько игрок разносторонне развит в напададении и его активность (количество штрафных (FT))

top_15_players2 = players_season[['Player', '2P', '3P', 'FT']].groupby('Player')\
    .sum().sort_values('2P', ascending=False).reset_index().head(15)\
            .plot(kind='bar', rot=45, stacked=True, x='Player', figsize=(20, 4), title='Атакующие навыки ТОП-15 играков по набранным очкам')

# %% [markdown]
# **гистограмма**

# %%
players_years = players_season[['Year', 'Player']].groupby('Player').count().sort_values('Year', ascending=False).reset_index()
players_years.head()
# Out:
#              Player  Year
# 0     Eddie Johnson    33
# 1     Mike Dunleavy    32
# 2  Gerald Henderson    29
# 3     Nazr Mohammed    28
# 4      Kevin Willis    27

# %%
#Распределение игроков по продолжительсти игры
# гисограмма показывает, что большая часть игроков проводит всего несколько сезонов, от 5 до 12 сезонов колебания незначительные

players_years.hist(figsize=(20, 4), bins=30)

# не соображу как по оси Y расположить лет игры, по X кол-во игроков, настроить плотность подписей оси
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000006BC779B188>]],
#       dtype=object)

# %% [markdown]
# **точечная диаграмма**

# %%
players_position = players_season[['Pos', 'PTS', 'Age']].groupby(['Pos', 'Age']).sum().reset_index()
players_position.head()
# Out:
#   Pos   Age       PTS
# 0   C  18.0     331.0
# 1   C  19.0    6339.0
# 2   C  20.0   25673.0
# 3   C  21.0   51157.0
# 4   C  22.0  145810.0

# %%
#график показывает распределение количества очков по возрастам играков. Самый результативный возраст 22-27 лет

sns.scatterplot(x='Age', y='PTS',data=players_position)
